# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrijanSingh/Assignmentx/blob/main/Copy_of_easy_OCR_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install tesseract-ocr
# !pip install pytesseract
# !pip install python-bidi
# !pip install easyocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from IPython.display import Image
import json

# %% [markdown]
# # New Section

# %%
Image("/content/plate2.png")

# %%
reader = easyocr.Reader(['en'])
# Out:
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import json
from PIL import Image
import pytesseract
from IPython.display import display

# Read text from the image
image_path = '/content/plate2.png'
image_path2='/content/name1.jpeg'
output = pytesseract.image_to_string(image_path).strip()

# Example data structure to associate a person with a number plate and an image
vehicle_data = {
    "7 /:BR 05 E5000": {
        "Name": "Arjun Kumar",
        "Address": "10, MG Road, Bangalore, Karnataka",
        "State": "Karnataka",
        "Vehicle": "Honda City"
    },
    "WB06F5977": {
        "Name": "Rajesh Gupta",
        "Address": "45, Park Street, Kolkata, West Bengal",
        "State": "West Bengal",
        "Vehicle": "Maruti Swift"
    },
    "22BH6517A": {
        "Name": "Sneha Sharma",
        "Address": "32, Gandhi Nagar, Mumbai, Maharashtra",
        "State": "Maharashtra",
        "Vehicle": "Hyundai i20"
    },
    "BR19G8869": {
        "Name": "Anil Singh",
        "Address": "15, Patna Junction, Patna, Bihar",
        "State": "Bihar",
        "Vehicle": "Tata Nexon"
    },
    "GJ23AU0819": {
        "Name": "Mehul Patel",
        "Address": "22, Ashram Road, Ahmedabad, Gujarat",
        "State": "Gujarat",
        "Vehicle": "Mahindra Thar"
    },
    "NO7CM4 123": {
        "Name": "Priya Iyer",
        "Address": "78, Anna Salai, Chennai, Tamil Nadu",
        "State": "Tamil Nadu",
        "Vehicle": "Ford EcoSport"
    },
    "BR05E5000": {
        "Name": "Manoj Kumar",
        "Address": "98, Rajendra Nagar, Patna, Bihar",
        "State": "Bihar",
        "Vehicle": "Renault Duster"
    },
    "MH43PR2356": {
        "Name": "Aishwarya Joshi",
        "Address": "54, Bandra West, Mumbai, Maharashtra",
        "State": "Maharashtra",
        "Vehicle": "BMW X5"
    },
    "e2BR 19 G 8869": {
        "Name": "Rakesh Singh",
        "Address": "12, Thangal Bazar, Imphal, Manipur",
        "State": "Manipur",
        "Vehicle": "Suzuki Baleno"
    },
    "TG090001": {
        "Name": "Suresh Reddy",
        "Address": "5, Banjara Hills, Hyderabad, Telangana",
        "State": "Telangana",
        "Vehicle": "Toyota Fortuner"
    },
    "[:TNO7CM4 123]": {
        "Name": "Kavya Nair",
        "Address": "34, Koramangala, Bangalore, Karnataka",
        "State": "Karnataka",
        "Vehicle": "Audi Q7"
    },
    "GA03MF4477": {
        "Name": "John D'Souza",
        "Address": "77, Panjim, Goa",
        "State": "Goa",
        "Vehicle": "Jeep Compass"
    },
    "HP03MF4477": {
        "Name": "Neha Verma",
        "Address": "20, Mall Road, Shimla, Himachal Pradesh",
        "State": "Himachal Pradesh",
        "Vehicle": "Maruti Alto"
    }
}

# Display the image
img = Image.open(image_path)
display(img)
img1=Image.open(image_path2)
display(img1)

# Check if the output matches any key in the vehicle_data dictionary
if output in vehicle_data:
    person_vehicle_data = vehicle_data[output]
    print(f"Vehicle Data for {output}:")
    print(json.dumps(person_vehicle_data, indent=4))
else:
    print(f"No data found for vehicle number: {output}")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=542x163>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=296x171>
# Vehicle Data for [:TNO7CM4 123]:
# {
#     "Name": "Kavya Nair",
#     "Address": "34, Koramangala, Bangalore, Karnataka",
#     "State": "Karnataka",
#     "Vehicle": "Audi Q7"
# }

# %%
output
# Out:
# '7 /:BR 05 E5000'

# %%
cord = output[-1][0]

# %%
cord
# Out:
# [[71, 43], [319, 43], [319, 103], [71, 103]]

# %%
a = list(zip(*cord))
a
# Out:
# [(71, 319, 319, 71), (43, 43, 103, 103)]

# %%
min(a[0])
# Out:
# 307

# %%
min(a[1])
# Out:
# 249

# %%
max(a[0])
# Out:
# 339

# %%
max(a[1])
# Out:
# 263

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_min, y_min
# Out:
# (307, 249)

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
x_max, y_max
# Out:
# (339, 263)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 30

# %%
image = cv2.imread('/content/bottle.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
